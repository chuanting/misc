# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np

# %%
folder = 'D:/Dataset/HighResolutionPopulation/'
country = 'KSA'
pop_file = folder + country + '/pop.csv'
bs_file = folder + country + '/BS.csv'
poly_file = folder + country + '/poly/poly.shp'
grid_file = folder + country + '/grid.geojson'

# %%
print('Loading population, bs, poly, and grid data...')
df_pop = pd.read_csv(pop_file)
df_bs = pd.read_csv(bs_file)
gdf_poly = gpd.read_file(poly_file)
gdf_poly.set_crs('epsg:4326', inplace=True)
grid = json.load(open(grid_file))
print('Creating GeoDataFrame from grid data...')
df_grid = gpd.GeoDataFrame.from_features(grid['features'])
df_grid['id'] = range(df_grid.shape[0])
df_grid.set_crs('epsg:4326', inplace=True)
# Out:
# Loading population, bs, poly, and grid data...
# Creating GeoDataFrame from grid data...
#                                                 geometry     id
# 0      POLYGON ((34.49430 32.27078, 34.56488 32.27078...      0
# 1      POLYGON ((34.49430 32.21686, 34.56488 32.21686...      1
# 2      POLYGON ((34.49430 32.16294, 34.56488 32.16294...      2
# 3      POLYGON ((34.49430 32.10902, 34.56488 32.10902...      3
# 4      POLYGON ((34.49430 32.05510, 34.56488 32.05510...      4
# ...                                                  ...    ...
# 89995  POLYGON ((55.59601 16.36391, 55.66659 16.36391...  89995
# 89996  POLYGON ((55.59601 16.30999, 55.66659 16.30999...  89996
# 89997  POLYGON ((55.59601 16.25607, 55.66659 16.25607...  89997
# 89998  POLYGON ((55.59601 16.20215, 55.66659 16.20215...  89998
# 89999  POLYGON ((55.59601 16.14823, 55.66659 16.14823...  89999
#
# [90000 rows x 2 columns]

# %%
print('Creating GeoDataFrame from population data...')
gdf_population = gpd.GeoDataFrame(df_pop,
                                  geometry=gpd.points_from_xy(df_pop.Lon, df_pop.Lat))
# Out:
# Creating GeoDataFrame from population data...

# %%
gdf_population.set_crs('epsg:4326', inplace=True)
print('Creating GeoDataFrame from bs data...')
gdf_bs = gpd.GeoDataFrame(df_bs,
                          geometry=gpd.points_from_xy(df_bs.lon, df_bs.lat))
gdf_bs.set_crs('epsg:4326', inplace=True)
# Out:
# Creating GeoDataFrame from bs data...
#        radio  mcc  net   area      cell  unit        lon        lat  range  \
# 0        GSM  420    1    338     56308     0  41.951981  19.531631   1000
# 1        GSM  420    1    457     32439     0  46.680644  24.698692   1000
# 2        GSM  420    3   2149     27691     0  41.405411  18.736496   1000
# 3        GSM  420    4  22101     12793     0  46.687637  24.701660   1000
# 4        GSM  420    1     74     21891     0  39.172440  21.564789   1000
# ...      ...  ...  ...    ...       ...   ...        ...        ...    ...
# 335984   LTE  420    3  42461  57826838     0  39.269676  21.466070   1000
# 335985   LTE  420    3  12461  57826858     0  39.269672  21.465914   1000
# 335986   LTE  420    3   1930  56300293     0  39.270645  21.464865   1000
# 335987   LTE  420    3  42461  57294132     0  39.270660  21.464842   1000
# 335988   LTE  420    4    212  55705094     0  46.702370  24.661798   1000
#
#         samples  changeable     created     updated  averageSignal  \
# 0             9           1  1459810864  1466902057              0
# 1            13           1  1459786728  1492150097              0
# 2             1           1  1459676483  1459676483              0
# 3            10           1  1459807892  1474807714              0
# 4             2           1  1459688718  1477201059              0
# ...         ...         ...         ...         ...            ...
# 335984        1           1  1582469837  1582469837              0
# 335985        1           1  1582475615  1582475615              0
# 335986        1           1  1584464403  1584464403              0
# 335987        1           1  1587491626  1587491626              0
# 335988        1           1  1591535153  1591535153              0
#
#                          geometry
# 0       POINT (41.95198 19.53163)
# 1       POINT (46.68064 24.69869)
# 2       POINT (41.40541 18.73650)
# 3       POINT (46.68764 24.70166)
# 4       POINT (39.17244 21.56479)
# ...                           ...
# 335984  POINT (39.26968 21.46607)
# 335985  POINT (39.26967 21.46591)
# 335986  POINT (39.27065 21.46486)
# 335987  POINT (39.27066 21.46484)
# 335988  POINT (46.70237 24.66180)
#
# [335989 rows x 15 columns]

# %%
print('Calculating # of populations per grid...')
pop_in_grid = gpd.sjoin(gdf_population, df_grid, op='within')
print('Calculating # of bs per grid...')
bs_in_grid = gpd.sjoin(gdf_bs, df_grid, op='within')
# Out:
# Calculating # of populations per grid...
# Calculating # of bs per grid...

# %%
bs_in_grid.drop(['index_right'], axis=1, inplace=True)

# %%
print('Removing the BS that are out of the poly...')
bs_in_poly = gpd.sjoin(bs_in_grid, gdf_poly, op='within')
# Out:
# Removing the BS that are out of the poly...

# %%
bs_in_poly = bs_in_poly[['radio', 'net', 'cell', 'lon', 'lat', 'geometry', 'id']]

# %%
bs_all_count = bs_in_poly[['id', 'geometry']].groupby('id').count().reset_index()

# %%
bs_all_count
# Out:
#          id  geometry
# 0       970         4
# 1      1854         2
# 2      1855       116
# 3      1856        16
# 4      1857         1
# ...     ...       ...
# 6029  82981         1
# 6030  83279         2
# 6031  83280         3
# 6032  83579         5
# 6033  88706         4
#
# [6034 rows x 2 columns]

# %%
df_grid_tunisia['id'] = range(df_grid_tunisia.shape[0])

# %%
df_grid_tunisia.head()
# Out:
#                                             geometry  id
# 0  POLYGON ((34.49430 32.27078, 34.56488 32.27078...   0
# 1  POLYGON ((34.49430 32.21686, 34.56488 32.21686...   1
# 2  POLYGON ((34.49430 32.16294, 34.56488 32.16294...   2
# 3  POLYGON ((34.49430 32.10902, 34.56488 32.10902...   3
# 4  POLYGON ((34.49430 32.05510, 34.56488 32.05510...   4

# %%
df_pop_tunisia.head()
# Out:
#          Lat        Lon  Population
# 0  27.000139  49.647917    6.226124
# 1  27.010417  49.657361    6.226124
# 2  26.984583  49.657639    6.226124
# 3  26.993194  49.659306    6.226124
# 4  27.003194  49.657917    6.226124

# %%
df_bs_tunisia.head()
# Out:
#   radio  mcc  net   area   cell  unit        lon        lat  range  samples  \
# 0   GSM  420    1    338  56308     0  41.951981  19.531631   1000        9
# 1   GSM  420    1    457  32439     0  46.680644  24.698692   1000       13
# 2   GSM  420    3   2149  27691     0  41.405411  18.736496   1000        1
# 3   GSM  420    4  22101  12793     0  46.687637  24.701660   1000       10
# 4   GSM  420    1     74  21891     0  39.172440  21.564789   1000        2
#
#    changeable     created     updated  averageSignal
# 0           1  1459810864  1466902057              0
# 1           1  1459786728  1492150097              0
# 2           1  1459676483  1459676483              0
# 3           1  1459807892  1474807714              0
# 4           1  1459688718  1477201059              0

# %%
gdf_population = gpd.GeoDataFrame(df_pop_tunisia, geometry=gpd.points_from_xy(df_pop_tunisia.Lon, df_pop_tunisia.Lat))

# %%
gdf_population.head()
# Out:
#          Lat        Lon  Population                   geometry
# 0  27.000139  49.647917    6.226124  POINT (49.64792 27.00014)
# 1  27.010417  49.657361    6.226124  POINT (49.65736 27.01042)
# 2  26.984583  49.657639    6.226124  POINT (49.65764 26.98458)
# 3  26.993194  49.659306    6.226124  POINT (49.65931 26.99319)
# 4  27.003194  49.657917    6.226124  POINT (49.65792 27.00319)

# %%
gdf_bs = gpd.GeoDataFrame(df_bs_tunisia, geometry=gpd.points_from_xy(df_bs_tunisia.lon, df_bs_tunisia.lat))

# %%
gdf_bs.set_crs('epsg:4326',inplace=True)
gdf_bs.head()
# Out:
#   radio  mcc  net   area   cell  unit        lon        lat  range  samples  \
# 0   GSM  420    1    338  56308     0  41.951981  19.531631   1000        9
# 1   GSM  420    1    457  32439     0  46.680644  24.698692   1000       13
# 2   GSM  420    3   2149  27691     0  41.405411  18.736496   1000        1
# 3   GSM  420    4  22101  12793     0  46.687637  24.701660   1000       10
# 4   GSM  420    1     74  21891     0  39.172440  21.564789   1000        2
#
#    changeable     created     updated  averageSignal  \
# 0           1  1459810864  1466902057              0
# 1           1  1459786728  1492150097              0
# 2           1  1459676483  1459676483              0
# 3           1  1459807892  1474807714              0
# 4           1  1459688718  1477201059              0
#
#                     geometry
# 0  POINT (41.95198 19.53163)
# 1  POINT (46.68064 24.69869)
# 2  POINT (41.40541 18.73650)
# 3  POINT (46.68764 24.70166)
# 4  POINT (39.17244 21.56479)

# %%
gdf_population
# Out:
#                Lat        Lon  Population                   geometry
# 0        27.000139  49.647917    6.226124  POINT (49.64792 27.00014)
# 1        27.010417  49.657361    6.226124  POINT (49.65736 27.01042)
# 2        26.984583  49.657639    6.226124  POINT (49.65764 26.98458)
# 3        26.993194  49.659306    6.226124  POINT (49.65931 26.99319)
# 4        27.003194  49.657917    6.226124  POINT (49.65792 27.00319)
# ...            ...        ...         ...                        ...
# 5279297  24.448750  39.605972    7.864090  POINT (39.60597 24.44875)
# 5279298  24.445972  39.608472    7.864090  POINT (39.60847 24.44597)
# 5279299  24.468472  39.636806    7.864090  POINT (39.63681 24.46847)
# 5279300  24.453194  39.612917    7.864090  POINT (39.61292 24.45319)
# 5279301  24.481250  39.632917    7.864090  POINT (39.63292 24.48125)
#
# [5279302 rows x 4 columns]

# %%
pointInPoly = gpd.sjoin(gdf_population, df_grid_tunisia, op='within')

# %%
pointInPoly.head()
# Out:
#          Lat        Lon  Population                   geometry  index_right  \
# 0  27.000139  49.647917    6.226124  POINT (49.64792 27.00014)        64297
# 1  27.010417  49.657361    6.226124  POINT (49.65736 27.01042)        64297
# 3  26.993194  49.659306    6.226124  POINT (49.65931 26.99319)        64297
# 4  27.003194  49.657917    6.226124  POINT (49.65792 27.00319)        64297
# 5  27.010694  49.613194    6.226124  POINT (49.61319 27.01069)        64297
#
#       id
# 0  64297
# 1  64297
# 3  64297
# 4  64297
# 5  64297

# %%
bsInPoly = gpd.sjoin(gdf_bs, df_grid_tunisia, op='within')
# Out:
# C:\Users\ZHANC0C\AppData\Local\Continuum\anaconda3\envs\tbb\lib\site-packages\ipykernel_launcher.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: None
#
#   """Entry point for launching an IPython kernel.

# %%
bsInPoly.head()
# Out:
#        radio  mcc  net   area      cell  unit        lon        lat  range  \
# 0        GSM  420    1    338     56308     0  41.951981  19.531631   1000
# 121594  UMTS  420    1   5123  14610915     0  41.951551  19.529357   2224
# 199826  UMTS  420    1    532  14590071     0  41.953354  19.542618   1000
# 208967  UMTS  420    4  61009  49248657     0  41.951981  19.531631   1000
# 208972  UMTS  420    1   5363  30569379     0  41.946487  19.520645   1000
#
#         samples  changeable     created     updated  averageSignal  \
# 0             9           1  1459810864  1466902057              0
# 121594       32           1  1458833369  1469786707              0
# 199826        1           1  1451265919  1451265919              0
# 208967        2           1  1459746465  1463961402              0
# 208972        2           1  1459768377  1461555966              0
#
#                          geometry  index_right     id
# 0       POINT (41.95198 19.53163)        31736  31736
# 121594  POINT (41.95155 19.52936)        31736  31736
# 199826  POINT (41.95335 19.54262)        31736  31736
# 208967  POINT (41.95198 19.53163)        31736  31736
# 208972  POINT (41.94649 19.52065)        31736  31736

# %%
bs_in_poly = gpd.sjoin(gdf_bs, pp,op='within')

# %%
bs_in_poly = bs_in_poly[['radio', 'net', 'cell', 'lon', 'lat', 'geometry']]

# %%
bs_in_poly.to_file('d:/ksa_bs.geojson', driver='GeoJSON')

# %%
bs_poly_GSM = bsInPoly[bsInPoly['radio']=='GSM']
bs_poly_UMTS = bsInPoly[bsInPoly['radio']=='UMTS']
bs_poly_LTE = bsInPoly[bsInPoly['radio']=='LTE']

# %%
bs_poly_GSM = bs_poly_GSM[['id', 'geometry']]
bs_poly_UMTS = bs_poly_UMTS[['id', 'geometry']]
bs_poly_LTE = bs_poly_LTE[['id', 'geometry']]

# %%
bs_GSM_count = bs_poly_GSM.groupby('id').count().reset_index()

# %%
bs_UMTS_count = bs_poly_UMTS.groupby('id').count().reset_index()
bs_LTE_count = bs_poly_LTE.groupby('id').count().reset_index()

# %%
bs_all_count = bsInPoly[['id', 'geometry']].groupby('id').count().reset_index()

# %%
pointInPoly = pointInPoly[['id', 'geometry']]
pop_count = pointInPoly.groupby('id').count().reset_index()

# %%
pop_count.head()
# Out:
#     id  geometry
# 0  375         4
# 1  377        30
# 2  378         5
# 3  674         8
# 4  675         1

# %%
pop_align = pd.merge(left=pop_count, right=df_grid_tunisia, left_on='id', right_on='id', how='right')

# %%
bs_align = pd.merge(left=bs_all_count, right=df_grid_tunisia, left_on='id', right_on='id', how='right')

# %%
pop_align.fillna(0, inplace=True)

# %%
bs_align.fillna(0, inplace=True)

# %%
pop_align.columns = ['id', 'pop', 'geometry']

# %%
bs_align.columns = ['id', 'bs', 'geometry']

# %%
pop_align.head()
# Out:
#    id  pop                                           geometry
# 0   0  0.0  POLYGON ((34.49430 32.27078, 34.56488 32.27078...
# 1   1  0.0  POLYGON ((34.49430 32.21686, 34.56488 32.21686...
# 2   2  0.0  POLYGON ((34.49430 32.16294, 34.56488 32.16294...
# 3   3  0.0  POLYGON ((34.49430 32.10902, 34.56488 32.10902...
# 4   4  0.0  POLYGON ((34.49430 32.05510, 34.56488 32.05510...

# %%
bs_align.head()
# Out:
#    id   bs                                           geometry
# 0   0  0.0  POLYGON ((34.49430 32.27078, 34.56488 32.27078...
# 1   1  0.0  POLYGON ((34.49430 32.21686, 34.56488 32.21686...
# 2   2  0.0  POLYGON ((34.49430 32.16294, 34.56488 32.16294...
# 3   3  0.0  POLYGON ((34.49430 32.10902, 34.56488 32.10902...
# 4   4  0.0  POLYGON ((34.49430 32.05510, 34.56488 32.05510...

# %%
pop_results = gpd.GeoDataFrame(pop_align)
pop_results.set_crs('epsg:4326',inplace=True)
# pop_final = gpd.sjoin(pop_results, pp,op='within')[['id_left', 'pop', 'geometry']]
pop_final = gpd.sjoin(pop_results, pp,op='within')[['id', 'pop', 'geometry']]

# %%
df_bounds = pop_final['geometry'].bounds
x = (df_bounds['minx'] + df_bounds['maxx']) / 2
y = (df_bounds['miny'] + df_bounds['maxy']) / 2
pop_final['lon'] = x.values
pop_final['lat'] = y.values
pop_final.to_file('d:/ksa_pop.geojson', driver='GeoJSON')

# %%
bs_results = gpd.GeoDataFrame(bs_align)
bs_results.set_crs('epsg:4326',inplace=True)
# bs_final = gpd.sjoin(bs_results, pp,op='within')[['id_left', 'bs', 'geometry']]
bs_final = gpd.sjoin(bs_results, pp,op='within')[['id', 'bs', 'geometry']]

# %%
df_bounds = pop_final['geometry'].bounds
x = (df_bounds['minx'] + df_bounds['maxx']) / 2
y = (df_bounds['miny'] + df_bounds['maxy']) / 2
bs_final['lat'] = x.values
bs_final['lon'] = y.values
bs_final.to_file('d:/ksa_bs.geojson', driver='GeoJSON')

# %%
bs_final
# Out:
#           id   bs                                           geometry  \
# 974      974  0.0  POLYGON ((34.70603 28.28058, 34.77660 28.28058...
# 975      975  0.0  POLYGON ((34.70603 28.22666, 34.77660 28.22666...
# 1271    1271  0.0  POLYGON ((34.77660 28.44235, 34.84718 28.44235...
# 1272    1272  0.0  POLYGON ((34.77660 28.38843, 34.84718 28.38843...
# 1273    1273  0.0  POLYGON ((34.77660 28.33451, 34.84718 28.33451...
# ...      ...  ...                                                ...
# 89589  89589  0.0  POLYGON ((55.52544 22.07960, 55.59601 22.07960...
# 89590  89590  0.0  POLYGON ((55.52544 22.02568, 55.59601 22.02568...
# 89591  89591  0.0  POLYGON ((55.52544 21.97176, 55.59601 21.97176...
# 89592  89592  0.0  POLYGON ((55.52544 21.91784, 55.59601 21.91784...
# 89593  89593  0.0  POLYGON ((55.52544 21.86391, 55.59601 21.86391...
#
#              lat        lon
# 974    34.741315  28.253624
# 975    34.741315  28.199703
# 1271   34.811889  28.415388
# 1272   34.811889  28.361467
# 1273   34.811889  28.307545
# ...          ...        ...
# 89589  55.560727  22.052641
# 89590  55.560727  21.998719
# 89591  55.560727  21.944798
# 89592  55.560727  21.890876
# 89593  55.560727  21.836954
#
# [43918 rows x 5 columns]

# %%
pop_final['bs'] = bs_final['bs'].values

# %%
all_final = pop_final.copy()

# %%
# all_final['pop'] = all_final['pop'] / all_final['pop'].max()
# all_final['bs'] = norm_final['bs']  / norm_final['bs'].max()

# %%
user_per_bs = 100
all_final['imbalance_index'] = all_final['pop'] / (all_final['bs'] * user_per_bs)
# all_final['imbalance_index'] = all_final['pop'] / all_final['bs']

# %%
all_final
# Out:
#           id   pop                                           geometry  \
# 974      974   0.0  POLYGON ((34.70603 28.28058, 34.77660 28.28058...
# 975      975   0.0  POLYGON ((34.70603 28.22666, 34.77660 28.22666...
# 1271    1271  40.0  POLYGON ((34.77660 28.44235, 34.84718 28.44235...
# 1272    1272   0.0  POLYGON ((34.77660 28.38843, 34.84718 28.38843...
# 1273    1273   2.0  POLYGON ((34.77660 28.33451, 34.84718 28.33451...
# ...      ...   ...                                                ...
# 89589  89589   0.0  POLYGON ((55.52544 22.07960, 55.59601 22.07960...
# 89590  89590   0.0  POLYGON ((55.52544 22.02568, 55.59601 22.02568...
# 89591  89591   0.0  POLYGON ((55.52544 21.97176, 55.59601 21.97176...
# 89592  89592   0.0  POLYGON ((55.52544 21.91784, 55.59601 21.91784...
# 89593  89593   0.0  POLYGON ((55.52544 21.86391, 55.59601 21.86391...
#
#              lon        lat   bs  imbalance_index
# 974    34.741315  28.253624  0.0              NaN
# 975    34.741315  28.199703  0.0              NaN
# 1271   34.811889  28.415388  0.0              inf
# 1272   34.811889  28.361467  0.0              NaN
# 1273   34.811889  28.307545  0.0              inf
# ...          ...        ...  ...              ...
# 89589  55.560727  22.052641  0.0              NaN
# 89590  55.560727  21.998719  0.0              NaN
# 89591  55.560727  21.944798  0.0              NaN
# 89592  55.560727  21.890876  0.0              NaN
# 89593  55.560727  21.836954  0.0              NaN
#
# [43918 rows x 7 columns]

# %%
all_final.loc[(all_final['pop']==0) & (all_final['bs']==0), 'imbalance_index'] = 0.0

# %%
# all_final.loc[all_final['imbalance_index']==np.inf, 'imbalance_index']
inf_imbalance = all_final.loc[all_final['imbalance_index']==np.inf, 'pop'] / user_per_bs
# inf_imbalance = all_final.loc[all_final['imbalance_index']==np.inf, 'pop']
all_final.loc[all_final['imbalance_index']==np.inf, 'imbalance_index'] = inf_imbalance.values

# %%
all_final.loc[all_final['bs']>=3, 'imbalance_index'] = 0.01

# %%
# user_threshold = 30
# zero_imbalance = all_final.loc[all_final['imbalance_index']==np.inf, 'pop'] / user_per_bs
# all_final.loc[all_final['imbalance_index']==np.inf, 'imbalance_index'] = 0

# %%
# # all_final.loc[all_final['imbalance_index']==np.inf, 'imbalance_index']
# inf_imbalance = all_final.loc[all_final['imbalance_index']==np.inf, 'pop'] / user_per_bs
# all_final.loc[all_final['imbalance_index']==np.inf, 'imbalance_index'] = inf_imbalance.values

# %%
all_final.to_file('d:/ksa_all_info_0.01_3.geojson', driver='GeoJSON')

# %%
bs_final.loc[(bs_final['bs']>5) & (bs_final['bs']>0)]
# Out:
#           id    bs                                           geometry  \
# 2158    2158   7.0  POLYGON ((34.98833 29.14333, 35.05890 29.14333...
# 2170    2170   7.0  POLYGON ((34.98833 28.49627, 35.05890 28.49627...
# 2171    2171   6.0  POLYGON ((34.98833 28.44235, 35.05890 28.44235...
# 2761    2761   9.0  POLYGON ((35.12947 28.98156, 35.20005 28.98156...
# 3062    3062   7.0  POLYGON ((35.20005 28.92764, 35.27062 28.92764...
# ...      ...   ...                                                ...
# 72450  72450  42.0  POLYGON ((51.50270 24.18254, 51.57328 24.18254...
# 79677  79677   6.0  POLYGON ((53.19649 22.72666, 53.26706 22.72666...
# 79977  79977   8.0  POLYGON ((53.26706 22.72666, 53.33764 22.72666...
# 82680  82680   6.0  POLYGON ((53.90223 22.56490, 53.97281 22.56490...
# 82980  82980  10.0  POLYGON ((53.97281 22.56490, 54.04338 22.56490...
#
#              lat        lon
# 2158   35.023612  29.116369
# 2170   35.023612  28.469310
# 2171   35.023612  28.415388
# 2761   35.164760  28.954605
# 3062   35.235335  28.900683
# ...          ...        ...
# 72450  51.537993  24.155583
# 79677  53.231775  22.699700
# 79977  53.302350  22.699700
# 82680  53.937518  22.537935
# 82980  54.008092  22.537935
#
# [2409 rows x 5 columns]

# %%
bs_final[bs_final['bs']>0].shape
# Out:
# (5676, 5)

# %%
pop_final.loc[bs_final['bs']>5]
# Out:
#           id     pop                                           geometry  \
# 2158    2158    98.0  POLYGON ((34.98833 29.14333, 35.05890 29.14333...
# 2170    2170  1420.0  POLYGON ((34.98833 28.49627, 35.05890 28.49627...
# 2171    2171  1210.0  POLYGON ((34.98833 28.44235, 35.05890 28.44235...
# 2761    2761    35.0  POLYGON ((35.12947 28.98156, 35.20005 28.98156...
# 3062    3062    40.0  POLYGON ((35.20005 28.92764, 35.27062 28.92764...
# ...      ...     ...                                                ...
# 72450  72450     0.0  POLYGON ((51.50270 24.18254, 51.57328 24.18254...
# 79677  79677    28.0  POLYGON ((53.19649 22.72666, 53.26706 22.72666...
# 79977  79977    55.0  POLYGON ((53.26706 22.72666, 53.33764 22.72666...
# 82680  82680   606.0  POLYGON ((53.90223 22.56490, 53.97281 22.56490...
# 82980  82980   230.0  POLYGON ((53.97281 22.56490, 54.04338 22.56490...
#
#              lon        lat    bs
# 2158   35.023612  29.116369   7.0
# 2170   35.023612  28.469310   7.0
# 2171   35.023612  28.415388   6.0
# 2761   35.164760  28.954605   9.0
# 3062   35.235335  28.900683   7.0
# ...          ...        ...   ...
# 72450  51.537993  24.155583  42.0
# 79677  53.231775  22.699700   6.0
# 79977  53.302350  22.699700   8.0
# 82680  53.937518  22.537935   6.0
# 82980  54.008092  22.537935  10.0
#
# [2409 rows x 6 columns]
